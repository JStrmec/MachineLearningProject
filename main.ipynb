# %%
#imports
from sklearn.utils import shuffle
import data_processing as d
import pandas as pd

# %%
df = pd.read_csv('datasets/VirusSample.csv')
shuffle(df).head(20)
# Out:
#                                                    file  \
# 8868           5b985fa1c47a66897619fffdd659ca3b85c7cd86
# 2212           4b2bf6fef39e98c09b7470ac584dccad2761ec57
# 1586           7bcc625c17e04358acbbf16c03e32db02169f976
# 4165           b03970b6fef4a71855461534b380cd3bde9892b1
# 2493           8e057ffff8100e67317f699ffdb29888cb456a55
# 8009           85eac6bcad2a9942bf06f2bf5a5f466738aa7873
# 3088           f5310fa8f5b7938428a0b308dcc7ef6a087b9869
# 5847           343a4ccbf283a34b94c2eecdcd43fee590056c14
# 7544           aeea975304633f8dbdc4a8dc5825d49767102526
# 4984           d0de1be1ca03c8d73fa74988df80a3525f000757
# 7039           76f5f60d672e28d896de71a72c7c5f95ba1f1cfd
# 5952           6ee09a6b2744042a893ee67f840bb5a08d7b9eef
# 2394           38529c1aad8dae2b76e725f3f2832918e17125a6
# 6172           322a120a1f61a63256dc720ce828b4a4e99e8b2f
# 6667           bb135ac200043f4146ae027f373bf84f68acfedc
# 4077           792f55f5a5f39a8b2345182c8dff15ac6516d98d
# ...
